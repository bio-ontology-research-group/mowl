# %% [markdown]
# # DL2Vec

# %%
import sys
sys.path.append("../../../")

import torch as th
import logging

from mowl.datasets.ppi_yeast import PPIYeastSlimDataset

from mowl.embeddings.graph_based.dl2vec.model import DL2Vec

logging.basicConfig(level=logging.DEBUG)

# %%
def main():
    dataset = PPIYeastSlimDataset()
    
    model = DL2Vec(
        dataset, 
        "model_out", 
        bidirectional_taxonomy=True,
        walking_method = "deepwalk",
        walk_length=50, 
        num_walks=100, 
        vector_size=10, 
        window=5,
        num_procs = 6
    )
    
    model.train()

# %%
main()
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.google.inject.internal.cglib.core.$ReflectUtils$2 (file:/home/zhapacfp/Github/mowl/gateway/build/distributions/gateway/lib/guice-4.0.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of com.google.inject.internal.cglib.core.$ReflectUtils$2
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# INFO:root:Generating graph from ontology...
# INFO: Number of ontology classes: 11020
# INFO:root:Finished graph generation
# INFO:root:Generating random walks...
# INFO:root:Walks generated
# INFO:root:Starting to train the Word2Vec model
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #10000, processed 500000 words, keeping 10988 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #20000, processed 1000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #30000, processed 1500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #40000, processed 2000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #50000, processed 2500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #60000, processed 3000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #70000, processed 3500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #80000, processed 4000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #90000, processed 4500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #100000, processed 5000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #110000, processed 5500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #120000, processed 6000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #130000, processed 6500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #140000, processed 7000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #150000, processed 7500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #160000, processed 8000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #170000, processed 8500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #180000, processed 9000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #190000, processed 9500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #200000, processed 10000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #210000, processed 10500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #220000, processed 11000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #230000, processed 11500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #240000, processed 12000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #250000, processed 12500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #260000, processed 13000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #270000, processed 13500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #280000, processed 14000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #290000, processed 14500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #300000, processed 15000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #310000, processed 15500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #320000, processed 16000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #330000, processed 16500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #340000, processed 17000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #350000, processed 17500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #360000, processed 18000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #370000, processed 18500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #380000, processed 19000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #390000, processed 19500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #400000, processed 20000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #410000, processed 20500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #420000, processed 21000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #430000, processed 21500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #440000, processed 22000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #450000, processed 22500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #460000, processed 23000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #470000, processed 23500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #480000, processed 24000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #490000, processed 24500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #500000, processed 25000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #510000, processed 25500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #520000, processed 26000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #530000, processed 26500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #540000, processed 27000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #550000, processed 27500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #560000, processed 28000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #570000, processed 28500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #580000, processed 29000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #590000, processed 29500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #600000, processed 30000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #610000, processed 30500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #620000, processed 31000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #630000, processed 31500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #640000, processed 32000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #650000, processed 32500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #660000, processed 33000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #670000, processed 33500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #680000, processed 34000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #690000, processed 34500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #700000, processed 35000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #710000, processed 35500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #720000, processed 36000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #730000, processed 36500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #740000, processed 37000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #750000, processed 37500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #760000, processed 38000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #770000, processed 38500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #780000, processed 39000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #790000, processed 39500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #800000, processed 40000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #810000, processed 40500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #820000, processed 41000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #830000, processed 41500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #840000, processed 42000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #850000, processed 42500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #860000, processed 43000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #870000, processed 43500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #880000, processed 44000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #890000, processed 44500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #900000, processed 45000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #910000, processed 45500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #920000, processed 46000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #930000, processed 46500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #940000, processed 47000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #950000, processed 47500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #960000, processed 48000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #970000, processed 48500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #980000, processed 49000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #990000, processed 49500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #1000000, processed 50000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #1010000, processed 50500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #1020000, processed 51000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #1030000, processed 51500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #1040000, processed 52000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #1050000, processed 52500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #1060000, processed 53000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #1070000, processed 53500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #1080000, processed 54000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #1090000, processed 54500000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:PROGRESS: at sentence #1100000, processed 55000000 words, keeping 11020 word types
# INFO:gensim.models.word2vec:collected 11020 word types from a corpus of 55100000 raw words and 1102000 sentences
# INFO:gensim.models.word2vec:Creating a fresh vocabulary
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=1 retains 11020 unique words (100.0%% of original 11020, drops 0)', 'datetime': '2021-12-21T16:19:07.855975', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-5.4.0-91-generic-x86_64-with-glibc2.27', 'event': 'prepare_vocab'}
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=1 leaves 55100000 word corpus (100.0%% of original 55100000, drops 0)', 'datetime': '2021-12-21T16:19:07.857116', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-5.4.0-91-generic-x86_64-with-glibc2.27', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:deleting the raw counts dictionary of 11020 items
# INFO:gensim.models.word2vec:sample=0.001 downsamples 3 most-common words
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 54796284.091648825 word corpus (99.4%% of prior 55100000)', 'datetime': '2021-12-21T16:19:07.899443', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-5.4.0-91-generic-x86_64-with-glibc2.27', 'event': 'prepare_vocab'}
# INFO:gensim.models.word2vec:estimated required memory for 11020 words and 10 dimensions: 6391600 bytes
# INFO:gensim.models.word2vec:resetting layer weights
# INFO:gensim.utils:Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2021-12-21T16:19:07.977346', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-5.4.0-91-generic-x86_64-with-glibc2.27', 'event': 'build_vocab'}
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'training model with 6 workers on 11020 vocabulary and 10 features, using sg=1 hs=0 sample=0.001 negative=5 window=5 shrink_windows=True', 'datetime': '2021-12-21T16:19:07.978015', 'gensim': '4.1.2', 'python': '3.9.7 | packaged by conda-forge | (default, Sep 29 2021, 19:20:46) \n[GCC 9.4.0]', 'platform': 'Linux-5.4.0-91-generic-x86_64-with-glibc2.27', 'event': 'train'}
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 1.76% examples, 964518 words/s, in_qsize 10, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 3.68% examples, 994088 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 5.44% examples, 984159 words/s, in_qsize 10, out_qsize 1
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 7.31% examples, 992820 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 9.26% examples, 1005462 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 11.07% examples, 1000933 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 12.90% examples, 999867 words/s, in_qsize 11, out_qsize 1
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 14.77% examples, 1001206 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 16.68% examples, 1004698 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 18.58% examples, 1006576 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 20.54% examples, 1012511 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 22.41% examples, 1012744 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 24.23% examples, 1009914 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 26.12% examples, 1011416 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 28.02% examples, 1013203 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 29.98% examples, 1016746 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 31.89% examples, 1018117 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 33.74% examples, 1017594 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 35.64% examples, 1018548 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 37.55% examples, 1019632 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 39.31% examples, 1017027 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 41.02% examples, 1013273 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 42.78% examples, 1010715 words/s, in_qsize 12, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 44.59% examples, 1009178 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 46.32% examples, 1006577 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 48.24% examples, 1008238 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 50.20% examples, 1010304 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 52.11% examples, 1011225 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 54.07% examples, 1012558 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at 55.97% examples, 1013484 words/s, in_qsize 11, out_qsize 0
# INFO:gensim.models.word2vec:EPOCH 1 - PROGRESS: at
0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_22457/451043146.py in <module>
# ----> 1 main()
#
# /tmp/ipykernel_22457/2689796260.py in main()
#      14     )
#      15
# ---> 16     model.train()
#
# ~/Github/mowl/mowl/examples/DL2Vec/../../../mowl/embeddings/graph_based/dl2vec/model.py in train(self)
#      81
#      82         sentences = gensim.models.word2vec.LineSentence(walks_outfile)
# ---> 83         model = gensim.models.Word2Vec(sentences, sg=1, min_count=1, vector_size=self.vector_size, window = self.window, epochs = self.num_walks, workers = self.num_procs)
#      84         logging.info("Word2Vec training finished")
#      85         logging.info(f"Saving model at {self.outfile}")
#
# ~/anaconda3/envs/mowl/lib/python3.9/site-packages/gensim/models/word2vec.py in __init__(self, sentences, corpus_file, vector_size, alpha, window, min_count, max_vocab_size, sample, seed, workers, min_alpha, sg, hs, negative, ns_exponent, cbow_mean, hashfxn, epochs, null_word, trim_rule, sorted_vocab, batch_words, compute_loss, callbacks, comment, max_final_vocab, shrink_windows)
#     424             self._check_corpus_sanity(corpus_iterable=corpus_iterable, corpus_file=corpus_file, passes=(epochs + 1))
#     425             self.build_vocab(corpus_iterable=corpus_iterable, corpus_file=corpus_file, trim_rule=trim_rule)
# --> 426             self.train(
#     427                 corpus_iterable=corpus_iterable, corpus_file=corpus_file, total_examples=self.corpus_count,
#     428                 total_words=self.corpus_total_words, epochs=self.epochs, start_alpha=self.alpha,
#
# ~/anaconda3/envs/mowl/lib/python3.9/site-packages/gensim/models/word2vec.py in train(self, corpus_iterable, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks, **kwargs)
#    1067
#    1068             if corpus_iterable is not None:
# -> 1069                 trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch(
#    1070                     corpus_iterable, cur_epoch=cur_epoch, total_examples=total_examples,
#    1071                     total_words=total_words, queue_factor=queue_factor, report_delay=report_delay,
#
# ~/anaconda3/envs/mowl/lib/python3.9/site-packages/gensim/models/word2vec.py in _train_epoch(self, data_iterable, cur_epoch, total_examples, total_words, queue_factor, report_delay, callbacks)
#    1428             thread.start()
#    1429
# -> 1430         trained_word_count, raw_word_count, job_tally = self._log_epoch_progress(
#    1431             progress_queue, job_queue, cur_epoch=cur_epoch, total_examples=total_examples,
#    1432             total_words=total_words, report_delay=report_delay, is_corpus_file_mode=False,
#
# ~/anaconda3/envs/mowl/lib/python3.9/site-packages/gensim/models/word2vec.py in _log_epoch_progress(self, progress_queue, job_queue, cur_epoch, total_examples, total_words, report_delay, is_corpus_file_mode)
#    1283
#    1284         while unfinished_worker_count > 0:
# -> 1285             report = progress_queue.get()  # blocks if workers too slow
#    1286             if report is None:  # a thread reporting that it finished
#    1287                 unfinished_worker_count -= 1
#
# ~/anaconda3/envs/mowl/lib/python3.9/queue.py in get(self, block, timeout)
#     169             elif timeout is None:
#     170                 while not self._qsize():
# --> 171                     self.not_empty.wait()
#     172             elif timeout < 0:
#     173                 raise ValueError("'timeout' must be a non-negative number")
#
# ~/anaconda3/envs/mowl/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:
